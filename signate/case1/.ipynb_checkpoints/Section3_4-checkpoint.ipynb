# %% [markdown]
# # PART4 欠損値を確認してみよう

# %% [markdown]
# ## おまじない

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# ジュピターノートブック上でグラフを表示させるための処理
# %matplotlib inline

# %% [markdown]
# ## データの読み込み
# - train.csvを読み込みましょう
# - 読み込んだものは変数trainに代入しましょう

# %%
train = pd.read_csv('train.csv')

# %% [markdown]
# ## trainの先頭行を確認しましょう

# %%
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %% [markdown]
# ## 各値が欠損値か否かを出力しましょう
# - 欠損とは何らかの理由で、データの値が入っていない状態のことをいいます
# - データ分析において欠損がある場合の対応はとても重要となります
# - 欠損の有無を確認する為にはisnull関数を使います
# - 欠損値の時、Trueと表示されます

# %%
# 欠損地の時にTrueになる。
train.head().isnull()
# Out:
#    datetime      y   week  soldout   name  kcal  remarks  event  payday  \
# 0     False  False  False    False  False  True     True   True    True
# 1     False  False  False    False  False  True     True   True    True
# 2     False  False  False    False  False  True     True   True    True
# 3     False  False  False    False  False  True     True   True    True
# 4     False  False  False    False  False  True     True   True    True
#
#    weather  precipitation  temperature
# 0    False          False        False
# 1    False          False        False
# 2    False          False        False
# 3    False          False        False
# 4    False          False        False

# %% [markdown]
# ## 各列（カラム）にTrueが１つ以上あるかないかを確かめてみましょう
# - isnull関数のあとにany関数を付け加えます。付け加える時はドット(.)で繋ぎます
# - 1つ以上欠損値を含んでいる場合、Trueと表示されます

# %%
# 1つ以上欠損値を含んでいる場合、Trueになる。
train.head().isnull().any()
# Out:
# datetime         False
# y                False
# week             False
# soldout          False
# name             False
# kcal              True
# remarks           True
# event             True
# payday            True
# weather          False
# precipitation    False
# temperature      False
# dtype: bool

# %% [markdown]
# ## 具体的に各列（カラム）に欠損値が幾つあるか数えてみましょう
# - isnull関数のあとにsum関数を付け加えます

# %%
train.isnull().sum()
# Out:
# datetime           0
# y                  0
# week               0
# soldout            0
# name               0
# kcal              41
# remarks          186
# event            193
# payday           197
# weather            0
# precipitation      0
# temperature        0
# dtype: int64

# %% [markdown]
# ## もう一度trainの先頭行を出力し、kcalに注目してみましょう

# %%
train.head()
# Out:
#      datetime    y week  soldout        name  kcal remarks event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   NaN     NaN   NaN     NaN
# 1  2013-11-19  101    火        1     手作りヒレカツ   NaN     NaN   NaN     NaN
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   NaN     NaN   NaN     NaN
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   NaN     NaN   NaN     NaN
# 4  2013-11-22  130    金        1    ビッグメンチカツ   NaN     NaN   NaN     NaN
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %% [markdown]
# ## 欠損値の処理をしましょう
# - 欠損値の処理は別のなんらかの値を代入（補間といいます）するか、欠損値を含む行を削除するかで対応します
# - ここではまず、欠損値を0で補間してみましょう
# - fillna関数を使います

# %%
# NaNになっている箇所を引数の値に変更する。
train.head().fillna(0)
#train.head()
# Out:
#      datetime    y week  soldout        name  kcal  remarks  event  payday  \
# 0  2013-11-18   90    月        0    厚切りイカフライ   0.0        0      0     0.0
# 1  2013-11-19  101    火        1     手作りヒレカツ   0.0        0      0     0.0
# 2  2013-11-20  118    水        0  白身魚唐揚げ野菜あん   0.0        0      0     0.0
# 3  2013-11-21  120    木        1      若鶏ピリ辛焼   0.0        0      0     0.0
# 4  2013-11-22  130    金        1    ビッグメンチカツ   0.0        0      0     0.0
#
#   weather precipitation  temperature
# 0      快晴            --         19.8
# 1      快晴            --         17.0
# 2      快晴            --         15.5
# 3      快晴            --         15.2
# 4      快晴            --         16.1

# %% [markdown]
# ## 今度は欠損値を削除してみましょう
# - dropna関数を使います
# - ある列に欠損値があった場合のみ、その行を削除したい場合はオプションとしてsubset=[ ]を使います

# %%
train.dropna()
# Out:
# Empty DataFrame
# Columns: [datetime, y, week, soldout, name, kcal, remarks, event, payday, weather, precipitation, temperature]
# Index: []

# %%
# ある列にkcalの欠損値があった場合、その行を削除する。
train.dropna(subset=['kcal']).head()
# Out:
#      datetime    y week  soldout          name   kcal remarks event  payday  \
# 28   2014-1-7  131    火        0  カレー入りソーセージカツ  404.0     NaN   NaN     NaN
# 29   2014-1-8  128    水        0        豚肉の生姜焼  462.0     NaN   NaN     NaN
# 30   2014-1-9  129    木        1        鶏チリソース  435.0     NaN   NaN     NaN
# 31  2014-1-10   87    金        0      手作りロースカツ  440.0     NaN   NaN     1.0
# 32  2014-1-14  129    火        1   鶏の照り焼きマスタード  376.0     NaN   NaN     NaN
#
#    weather precipitation  temperature
# 28      快晴            --          7.3
# 29       曇            --          9.8
# 30       曇            --         10.9
# 31      快晴            --          5.1
# 32      晴れ            --          5.8

# %% [markdown]
# ## precipitationには本当に欠損値がないか確認してみましょう
# - 行の中の値がそれぞれ幾つあるかを確認したい場合は、value_counts関数を使います

# %%
train['precipitation'].value_counts()
# Out:
# --     169
# 0       23
# 0.5      9
# 1.5      2
# 6.5      1
# 6        1
# 1        1
# 2.5      1
# Name: precipitation, dtype: int64
